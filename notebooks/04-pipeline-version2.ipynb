# %% [markdown]
# Make sure to use `sagemaker==2.93.0`

# %%
# !pwd
# Out:
# /home/ec2-user/SageMaker/code-repo

# %%
! pip install --quiet sagemaker==2.93.0

# %%
import boto3
import sagemaker
import sagemaker.session
from sagemaker.workflow.pipeline_context import PipelineSession

# %%
sagemaker.__version__
# Out:
# '2.93.0'

# %%
region = boto3.Session().region_name
role = sagemaker.get_execution_role()
boto_session = boto3.Session()
sagemaker_session = sagemaker.Session(boto_session=boto_session)
default_bucket = sagemaker_session.default_bucket()

# %%
def get_sagemaker_client(region):
    """Gets the sagemaker client.

    Args:
        region: the aws region to start the session
        default_bucket: the bucket to use for storing the artifacts

    Returns:
        `sagemaker.session.Session instance
    """
    boto_session = boto3.Session(region_name=region)
    sagemaker_client = boto_session.client("sagemaker")
    return sagemaker_client


def get_session(region, default_bucket):
    """Gets the sagemaker session based on the region.

    Args:
        region: the aws region to start the session
        default_bucket: the bucket to use for storing the artifacts

    Returns:
        `sagemaker.session.Session instance
    """

    boto_session = boto3.Session(region_name=region)

    sagemaker_client = boto_session.client("sagemaker")
    runtime_client = boto_session.client("sagemaker-runtime")
    return sagemaker.session.Session(
        boto_session=boto_session,
        sagemaker_client=sagemaker_client,
        sagemaker_runtime_client=runtime_client,
        default_bucket=default_bucket,
    )


def get_pipeline_session(region, default_bucket):
    """Gets the pipeline session based on the region.

    Args:
        region: the aws region to start the session
        default_bucket: the bucket to use for storing the artifacts

    Returns:
        PipelineSession instance
    """

    boto_session = boto3.Session(region_name=region)
    sagemaker_client = boto_session.client("sagemaker")

    return PipelineSession(
        boto_session=boto_session,
        sagemaker_client=sagemaker_client,
        default_bucket=default_bucket,
    )

# %%
sagemaker_session = get_session(region, default_bucket)
role = sagemaker.session.get_execution_role(sagemaker_session)
pipeline_session = get_pipeline_session(region, default_bucket)

# %%
base_job_name = "pipeline-scene"

# %%
from sagemaker.workflow.parameters import (
    ParameterFloat,
    ParameterInteger,
    ParameterString,
)

# %% [markdown]
# ## Processing Step

# %%
from sagemaker.processing import FrameworkProcessor, ProcessingInput, ProcessingOutput
from sagemaker.sklearn import SKLearn

# %%
dvc_repo_url = ParameterString(
    name="DVCRepoURL", default_value="codecommit::ap-south-1://sagemaker-scene"
)
dvc_branch = ParameterString(name="DVCBranch", default_value="pipeline-processed-dataset")

# %%
processor = FrameworkProcessor(
    estimator_cls=SKLearn,
    framework_version="0.23-1",
    # instance_type="ml.m5.xlarge",
    instance_type="local",
    instance_count=1,
    image_uri="441249477288.dkr.ecr.ap-south-1.amazonaws.com/sagemaker-training:latest",
    base_job_name=f"{base_job_name}/preprocess-scene-dataset",
    sagemaker_session=pipeline_session,
    role=role,
    env={
        # "DVC_REPO_URL": dvc_repo_url,
        # "DVC_BRANCH": dvc_branch,
        "DVC_REPO_URL": "codecommit::ap-south-1://sagemaker-scene",
        "DVC_BRANCH": "pipeline-processed-dataset",
        "GIT_USER": "gokul-pv",
        "GIT_EMAIL": "25975535+gokul-pv@users.noreply.github.com",
    },
)

# %%
from sagemaker.workflow.steps import ProcessingStep

# %%
input_dataset = ParameterString(
    name="InputDatasetZip",
    default_value="s3://sagemaker-ap-south-1-441249477288/dataset/intel.zip",
)
annotated_meta = ParameterString(
    name="AnnotationMetaData", default_value="s3://sagemaker-ap-south-1-441249477288/annotations/"
)
annotated_data = ParameterString(
    name="AnnotatedData", default_value="s3://sagemaker-ap-south-1-441249477288/Predictions/"
)

# %%
processing_step_args = processor.run(
    code="pipelines/preprocess.py",
    source_dir="sagemaker-kidu",
    inputs=[
        ProcessingInput(
            input_name="data",
            # source=input_dataset,
            source="s3://sagemaker-ap-south-1-441249477288/dataset/intel.zip",
            destination="/opt/ml/processing/input",
        ),
        ProcessingInput(
            input_name="annotated_meta",
            # source=annotated_meta,
            source="s3://sagemaker-ap-south-1-441249477288/old-data/label-studio/",
            destination="/opt/ml/processing/input/annotations/meta",
        ),
        ProcessingInput(
            input_name="annotated_data",
            # source=annotated_data,
            source="s3://sagemaker-ap-south-1-441249477288/old-data/prediction/",
            destination="/opt/ml/processing/input/annotations/data",
        ),
    ],
    outputs=[
        ProcessingOutput(output_name="train", source="/opt/ml/processing/dataset/train"),
        ProcessingOutput(output_name="test", source="/opt/ml/processing/dataset/test"),
    ],
)

# %%
from sagemaker.workflow.steps import CacheConfig

cache_config = CacheConfig(enable_caching=True, expire_after="30d")

# %%
step_process = ProcessingStep(
    name="PreprocessSceneClassifierDataset",
    step_args=processing_step_args,
    cache_config=cache_config,
)

# %%
step_process

# %% [markdown]
# ## Train Step

# %%
from sagemaker.debugger import TensorBoardOutputConfig
from sagemaker.pytorch import PyTorch
from sagemaker.workflow.steps import ProcessingStep, TrainingStep

# %%
tensorboard_output_config = TensorBoardOutputConfig(
    s3_output_path=f"s3://{default_bucket}/sagemaker-scene-logs-pipeline",
    container_local_output_path="/opt/ml/output/tensorboard",
)

# %%
model_name = ParameterString(name="Model", default_value="spnasnet_100")
batch_size = ParameterString(name="Batch_Size", default_value="128")
optimizer = ParameterString(name="Optimizer", default_value="torch.optim.Adam")
learning_rate = ParameterString(name="Learning_Rate", default_value="0.001")
use_augmentation_pipeline = ParameterString(name="Augmentation_Pipeline", default_value="1")
# train_data_s3 = ParameterString(name="Train_Dataset_S3", default_value=step_process.properties.ProcessingOutputConfig.Outputs["train"].S3Output.S3Uri)
# test_data_s3 = ParameterString(name="Test_Dataset_S3", default_value=step_process.properties.ProcessingOutputConfig.Outputs["test"].S3Output.S3Uri)

# %%
pt_estimator = PyTorch(
    base_job_name=f"{base_job_name}/training-scene-pipeline",
    image_uri="441249477288.dkr.ecr.ap-south-1.amazonaws.com/sagemaker-training:latest",
    source_dir="sagemaker-kidu",
    entry_point="pipelines/train_pipeline.py",
    # sagemaker_session=pipeline_session,
    role=role,
    instance_count=1,
    # instance_type="ml.g4dn.xlarge",
    instance_type="local",
    tensorboard_output_config=tensorboard_output_config,
    # use_spot_instances=True,
    max_wait=1800,
    max_run=1500,
    environment={
        "GIT_USER": "gokul-pv",
        "GIT_EMAIL": "25975535+gokul-pv@users.noreply.github.com",
        # "MODEL": model_name,
        # "BATCH_SIZE": batch_size,
        # "OPTIMIZER": optimizer,
        # "LR": learning_rate,
        # "AUGMENTATION": use_augmentation_pipeline
        "MODEL": "spnasnet_100",
        "BATCH_SIZE": "16",
        "OPTIMIZER": "torch.optim.Adam",
        "LR": "0.0005",
        "AUGMENTATION": "1",
    },
)

# %%
from sagemaker.inputs import TrainingInput

# %%
estimator_step_args = pt_estimator.fit(
    {
        "train": "s3://sagemaker-ap-south-1-441249477288/pipeline-scene/preprocess-scene-dataset-2023-01-29-14-40-58-863/output/train/",
        "test": "s3://sagemaker-ap-south-1-441249477288/pipeline-scene/preprocess-scene-dataset-2023-01-29-14-40-58-863/output/test/",
        # 'train': TrainingInput(s3_data=step_process.properties.ProcessingOutputConfig.Outputs["train"].S3Output.S3Uri),
        # 'test': TrainingInput(s3_data=step_process.properties.ProcessingOutputConfig.Outputs["test"].S3Output.S3Uri)
    }
)
# Out:
# Creating 93vbopgk1t-algo-1-tnbe6 ...
# Creating 93vbopgk1t-algo-1-tnbe6 ... done
# Attaching to 93vbopgk1t-algo-1-tnbe6
# 93vbopgk1t-algo-1-tnbe6 | sed: can't read changehostname.c: No such file or directory
# 93vbopgk1t-algo-1-tnbe6 | gcc: error: changehostname.c: No such file or directory
# 93vbopgk1t-algo-1-tnbe6 | gcc: fatal error: no input files
# 93vbopgk1t-algo-1-tnbe6 | compilation terminated.
# 93vbopgk1t-algo-1-tnbe6 | gcc: error: changehostname.o: No such file or directory
# 93vbopgk1t-algo-1-tnbe6 | ERROR: ld.so: object '/libchangehostname.so' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,090 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,093 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,095 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,105 sagemaker-training-toolkit INFO     instance_groups entry not present in resource_config
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,109 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,113 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,287 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,290 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,302 sagemaker-training-toolkit INFO     instance_groups entry not present in resource_config
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,309 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,311 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,320 sagemaker-training-toolkit INFO     instance_groups entry not present in resource_config
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,327 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,330 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,339 sagemaker-training-toolkit INFO     instance_groups entry not present in resource_config
# 93vbopgk1t-algo-1-tnbe6 | 2023-02-05 14:40:28,343 sagemaker-training-toolkit INFO     Invoking user script
# 93vbopgk1t-algo-1-tnbe6 |
# 93vbopgk1t-algo-1-tnbe6 | Training Env:
# 93vbopgk1t-algo-1-tnbe6 |
# 93vbopgk1t-algo-1-tnbe6 | {
# 93vbopgk1t-algo-1-tnbe6 |     "additional_framework_parameters": {},
# 93vbopgk1t-algo-1-tnbe6 |     "channel_input_dirs": {
# 93vbopgk1t-algo-1-tnbe6 |         "train": "/opt/ml/input/data/train",
# 93vbopgk1t-algo-1-tnbe6 |         "test": "/opt/ml/input/data/test"
# 93vbopgk1t-algo-1-tnbe6 |     },
# 93vbopgk1t-algo-1-tnbe6 |     "current_host": "algo-1-tnbe6",
# 93vbopgk1t-algo-1-tnbe6 |     "current_instance_group": "homogeneousCluster",
# 93vbopgk1t-algo-1-tnbe6 |     "current_instance_group_hosts": [],
# 93vbopgk1t-algo-1-tnbe6 |     "current_instance_type": "local",
# 93vbopgk1t-algo-1-tnbe6 |     "distribution_hosts": [
# 93vbopgk1t-algo-1-tnbe6 |         "algo-1-tnbe6"
# 93vbopgk1t-algo-1-tnbe6 |     ],
# 93vbopgk1t-algo-1-tnbe6 |     "distribution_instance_groups": [],
# 93vbopgk1t-algo-1-tnbe6 |     "framework_module": "sagemaker_pytorch_container.training:main",
# 93vbopgk1t-algo-1-tnbe6 |     "hosts": [
# 93vbopgk1t-algo-1-tnbe6 |         "algo-1-tnbe6"
# 93vbopgk1t-algo-1-tnbe6 |     ],
# 93vbopgk1t-algo-1-tnbe6 |     "hyperparameters": {},
# 93vbopgk1t-algo-1-tnbe6 |     "input_config_dir": "/opt/ml/input/config",
# 93vbopgk1t-algo-1-tnbe6 |     "input_data_config": {
# 93vbopgk1t-algo-1-tnbe6 |         "train": {
# 93vbopgk1t-algo-1-tnbe6 |             "TrainingInputMode": "File"
# 93vbopgk1t-algo-1-tnbe6 |         },
# 93vbopgk1t-algo-1-tnbe6 |         "test": {
# 93vbopgk1t-algo-1-tnbe6 |             "TrainingInputMode": "File"
# 93vbopgk1t-algo-1-tnbe6 |         }
# 93vbopgk1t-algo-1-tnbe6 |     },
# 93vbopgk1t-algo-1-tnbe6 |     "input_dir": "/opt/ml/input",
# 93vbopgk1t-algo-1-tnbe6 |     "instance_groups": [],
# 93vbopgk1t-algo-1-tnbe6 |     "instance_groups_dict": {},
# 93vbopgk1t-algo-1-tnbe6 |     "is_hetero": false,
# 93vbopgk1t-algo-1-tnbe6 |     "is_master": true,
# 93vbopgk1t-algo-1-tnbe6 |     "is_modelparallel_enabled": null,
# 93vbopgk1t-algo-1-tnbe6 |     "is_smddpmprun_installed": false,
# 93vbopgk1t-algo-1-tnbe6 |     "job_name": "pipeline-scene/training-scene-pipeline-2023-02-05-14-39-40-522",
# 93vbopgk1t-algo-1-tnbe6 |     "log_level": 20,
# 93vbopgk1t-algo-1-tnbe6 |     "master_hostname": "algo-1-tnbe6",
# 93vbopgk1t-algo-1-tnbe6 |     "model_dir": "/opt/ml/model",
# 93vbopgk1t-algo-1-tnbe6 |     "module_dir": "s3://sagemaker-ap-south-1-441249477288/pipeline-scene/training-scene-pipeline-2023-02-05-14-39-40-522/source/sourcedir.tar.gz",
# 93vbopgk1t-algo-1-tnbe6 |     "module_name": "pipelines/train_pipeline",
# 93vbopgk1t-algo-1-tnbe6 |     "network_interface_name": "eth0",
# 93vbopgk1t-algo-1-tnbe6 |     "num_cpus": 2,
# 93vbopgk1t-algo-1-tnbe6 |     "num_gpus": 0,
# 93vbopgk1t-algo-1-tnbe6 |     "num_neurons": 0,
# 93vbopgk1t-algo-1-tnbe6 |     "output_data_dir": "/opt/ml/output/data",
# 93vbopgk1t-algo-1-tnbe6 |     "output_dir": "/opt/ml/output",
# 93vbopgk1t-algo-1-tnbe6 |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# 93vbopgk1t-algo-1-tnbe6 |     "resource_config": {
# 93vbopgk1t-algo-1-tnbe6 |         "current_host": "algo-1-tnbe6",
# 93vbopgk1t-algo-1-tnbe6 |         "hosts": [
# 93vbopgk1t-algo-1-tnbe6 |             "algo-1-tnbe6"
# 93vbopgk1t-algo-1-tnbe6 |         ]
# 93vbopgk1t-algo-1-tnbe6 |     },
# 93vbopgk1t-algo-1-tnbe6 |     "user_entry_point": "pipelines/train_pipeline.py"
# 93vbopgk1t-algo-1-tnbe6 | }
# 93vbopgk1t-algo-1-tnbe6 |
# 93vbopgk1t-algo-1-tnbe6 | Environment variables:
# 93vbopgk1t-algo-1-tnbe6 |
# 93vbopgk1t-algo-1-tnbe6 | SM_HOSTS=["algo-1-tnbe6"]
# 93vbopgk1t-algo-1-tnbe6 | SM_NETWORK_INTERFACE_NAME=eth0
# 93vbopgk1t-algo-1-tnbe6 | SM_HPS={}
# 93vbopgk1t-algo-1-tnbe6 | SM_USER_ENTRY_POINT=pipelines/train_pipeline.py
# 93vbopgk1t-algo-1-tnbe6 | SM_FRAMEWORK_PARAMS={}
# 93vbopgk1t-algo-1-tnbe6 | SM_RESOURCE_CONFIG={"current_host":"algo-1-tnbe6","hosts":["algo-1-tnbe6"]}
# 93vbopgk1t-algo-1-tnbe6 | SM_INPUT_DATA_CONFIG={"test":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"}}
# 93vbopgk1t-algo-1-tnbe6 | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# 93vbopgk1t-algo-1-tnbe6 | SM_CHANNELS=["test","train"]
# 93vbopgk1t-algo-1-tnbe6 | SM_CURRENT_HOST=algo-1-tnbe6
# 93vbopgk1t-algo-1-tnbe6 | SM_CURRENT_INSTANCE_TYPE=local
# 93vbopgk1t-algo-1-tnbe6 | SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# 93vbopgk1t-algo-1-tnbe6 | SM_CURRENT_INSTANCE_GROUP_HOSTS=[]
# 93vbopgk1t-algo-1-tnbe6 | SM_INSTANCE_GROUPS=[]
# 93vbopgk1t-algo-1-tnbe6 | SM_INSTANCE_GROUPS_DICT={}
# 93vbopgk1t-algo-1-tnbe6 | SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# 93vbopgk1t-algo-1-tnbe6 | SM_IS_HETERO=false
# 93vbopgk1t-algo-1-tnbe6 | SM_MODULE_NAME=pipelines/train_pipeline
# 93vbopgk1t-algo-1-tnbe6 | SM_LOG_LEVEL=20
# 93vbopgk1t-algo-1-tnbe6 | SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# 93vbopgk1t-algo-1-tnbe6 | SM_INPUT_DIR=/opt/ml/input
# 93vbopgk1t-algo-1-tnbe6 | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# 93vbopgk1t-algo-1-tnbe6 | SM_OUTPUT_DIR=/opt/ml/output
# 93vbopgk1t-algo-1-tnbe6 | SM_NUM_CPUS=2
# 93vbopgk1t-algo-1-tnbe6 | SM_NUM_GPUS=0
# 93vbopgk1t-algo-1-tnbe6 | SM_NUM_NEURONS=0
# 93vbopgk1t-algo-1-tnbe6 | SM_MODEL_DIR=/opt/ml/model
# 93vbopgk1t-algo-1-tnbe6 | SM_MODULE_DIR=s3://sagemaker-ap-south-1-441249477288/pipeline-scene/training-scene-pipeline-2023-02-05-14-39-40-522/source/sourcedir.tar.gz
# 93vbopgk1t-algo-1-tnbe6 | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1-tnbe6","current_instance_group":"homogeneousCluster","current_instance_group_hosts":[],"current_instance_type":"local","distribution_hosts":["algo-1-tnbe6"],"distribution_instance_groups":[],"framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1-tnbe6"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":[],"instance_groups_dict":{},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"job_name":"pipeline-scene/training-scene-pipeline-2023-02-05-14-39-40-522","log_level":20,"master_hostname":"algo-1-tnbe6","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-south-1-441249477288/pipeline-scene/training-scene-pipeline-2023-02-05-14-39-40-522/source/sourcedir.tar.gz","module_name":"pipelines/train_pipeline","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-tnbe6","hosts":["algo-1-tnbe6"]},"user_entry_point":"pipelines/train_pipeline.py"}
# 93vbopgk1t-algo-1-tnbe6 | SM_USER_ARGS=[]
# 93vbopgk1t-algo-1-tnbe6 | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# 93vbopgk1t-algo-1-tnbe6 | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# 93vbopgk1t-algo-1-tnbe6 | SM_CHANNEL_TEST=/opt/ml/input/data/test
# 93vbopgk1t-algo-1-tnbe6 | PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python38.zip:/opt/conda/lib/python3.8:/opt/conda/lib/python3.8/lib-dynload:/opt/conda/lib/python3.8/site-packages:/opt/conda/lib/python3.8/site-packages/smdebug-1.0.22b20221118-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument-3.4.2-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument_cext-0.2.4-py3.8-linux-x86_64.egg
# 93vbopgk1t-algo-1-tnbe6 |
# 93vbopgk1t-algo-1-tnbe6 | Invoking script with the following command:
# 93vbopgk1t-algo-1-tnbe6 |
# 93vbopgk1t-algo-1-tnbe6 | /opt/conda/bin/python3.8 pipelines/train_pipeline.py
# 93vbopgk1t-algo-1-tnbe6 |
# 93vbopgk1t-algo-1-tnbe6 |
# 93vbopgk1t-algo-1-tnbe6 | ERROR: ld.so: object '/libchangehostname.so' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# 93vbopgk1t-algo-1-tnbe6 | ERROR: ld.so: object '/libchangehostname.so' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# 93vbopgk1t-algo-1-tnbe6 | ERROR: ld.so: object '/libchangehostname.so' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# 93vbopgk1t-algo-1-tnbe6 | ERROR: ld.so: object '/libchangehostname.so' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# 93vbopgk1t-algo-1-tnbe6 | ERROR: ld.so: object '/libchangehostname.so' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# 93vbopgk1t-algo-1-tnbe6 | ERROR: ld.so: object '/libchangehostname.so' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# 93vbopgk1t-algo-1-tnbe6 | :: Class names:
# 93vbopgk1t-algo-1-tnbe6 |
# 93vbopgk1t-algo-1-tnbe6 | ['buildings', 'forest']
# 93vbopgk1t-algo-1-tnbe6 |
# 93vbopgk1t-algo-1-tnbe6 | :: Training ...
# 93vbopgk1t-algo-1-tnbe6 |
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:32,751][src.utils.utils][INFO] - Enforcing tags! <cfg.extras.enforce_tags=True>
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:32,758][src.utils.utils][INFO] - Printing config tree with Rich! <cfg.extras.print_config=True>
# 93vbopgk1t-algo-1-tnbe6 | CONFIG
# 93vbopgk1t-algo-1-tnbe6 | ├── data
# 93vbopgk1t-algo-1-tnbe6 | │   └── _target_: src.data.intel_scene_datamodule.IntelSceneDataModule
# 93vbopgk1t-algo-1-tnbe6 | │       train_data_dir: /opt/ml/input/data/train
# 93vbopgk1t-algo-1-tnbe6 | │       test_data_dir: /opt/ml/input/data/test
# 93vbopgk1t-algo-1-tnbe6 | │       batch_size: 16
# 93vbopgk1t-algo-1-tnbe6 | │       train_val_test_split:
# 93vbopgk1t-algo-1-tnbe6 | │       - 13600
# 93vbopgk1t-algo-1-tnbe6 | │       - 1700
# 93vbopgk1t-algo-1-tnbe6 | │       - 1734
# 93vbopgk1t-algo-1-tnbe6 | │       num_workers: 2
# 93vbopgk1t-algo-1-tnbe6 | │       pin_memory: false
# 93vbopgk1t-algo-1-tnbe6 | │       use_augmentation_pipeline: 1
# 93vbopgk1t-algo-1-tnbe6 | │
# 93vbopgk1t-algo-1-tnbe6 | ├── model
# 93vbopgk1t-algo-1-tnbe6 | │   └── _target_: src.models.timm_module.Timm_LitModule
# 93vbopgk1t-algo-1-tnbe6 | │       optimizer:
# 93vbopgk1t-algo-1-tnbe6 | │         _target_: torch.optim.Adam
# 93vbopgk1t-algo-1-tnbe6 | │         _partial_: true
# 93vbopgk1t-algo-1-tnbe6 | │       scheduler:
# 93vbopgk1t-algo-1-tnbe6 | │         _target_: torch.optim.lr_scheduler.OneCycleLR
# 93vbopgk1t-algo-1-tnbe6 | │         _partial_: true
# 93vbopgk1t-algo-1-tnbe6 | │         max_lr: 0.0005
# 93vbopgk1t-algo-1-tnbe6 | │         epochs: 10
# 93vbopgk1t-algo-1-tnbe6 | │         steps_per_epoch: 850
# 93vbopgk1t-algo-1-tnbe6 | │       net:
# 93vbopgk1t-algo-1-tnbe6 | │         _target_: timm.models.create_model
# 93vbopgk1t-algo-1-tnbe6 | │         model_name: spnasnet_100
# 93vbopgk1t-algo-1-tnbe6 | │         pretrained: true
# 93vbopgk1t-algo-1-tnbe6 | │         in_chans: 3
# 93vbopgk1t-algo-1-tnbe6 | │         num_classes: 6
# 93vbopgk1t-algo-1-tnbe6 | │       num_class: 6
# 93vbopgk1t-algo-1-tnbe6 | │       learning_rate: 5.0e-05
# 93vbopgk1t-algo-1-tnbe6 | │
# 93vbopgk1t-algo-1-tnbe6 | ├── callbacks
# 93vbopgk1t-algo-1-tnbe6 | │   └── model_checkpoint:
# 93vbopgk1t-algo-1-tnbe6 | │         _target_: pytorch_lightning.callbacks.ModelCheckpoint
# 93vbopgk1t-algo-1-tnbe6 | │         dirpath: /opt/ml/model
# 93vbopgk1t-algo-1-tnbe6 | │         filename: epoch_{epoch:03d}
# 93vbopgk1t-algo-1-tnbe6 | │         monitor: val/acc
# 93vbopgk1t-algo-1-tnbe6 | │         verbose: false
# 93vbopgk1t-algo-1-tnbe6 | │         save_last: true
# 93vbopgk1t-algo-1-tnbe6 | │         save_top_k: 1
# 93vbopgk1t-algo-1-tnbe6 | │         mode: max
# 93vbopgk1t-algo-1-tnbe6 | │         auto_insert_metric_name: false
# 93vbopgk1t-algo-1-tnbe6 | │         save_weights_only: false
# 93vbopgk1t-algo-1-tnbe6 | │         every_n_train_steps: null
# 93vbopgk1t-algo-1-tnbe6 | │         train_time_interval: null
# 93vbopgk1t-algo-1-tnbe6 | │         every_n_epochs: null
# 93vbopgk1t-algo-1-tnbe6 | │         save_on_train_epoch_end: null
# 93vbopgk1t-algo-1-tnbe6 | │       early_stopping:
# 93vbopgk1t-algo-1-tnbe6 | │         _target_: pytorch_lightning.callbacks.EarlyStopping
# 93vbopgk1t-algo-1-tnbe6 | │         monitor: val/acc
# 93vbopgk1t-algo-1-tnbe6 | │         min_delta: 0.0
# 93vbopgk1t-algo-1-tnbe6 | │         patience: 100
# 93vbopgk1t-algo-1-tnbe6 | │         verbose: false
# 93vbopgk1t-algo-1-tnbe6 | │         mode: max
# 93vbopgk1t-algo-1-tnbe6 | │         strict: true
# 93vbopgk1t-algo-1-tnbe6 | │         check_finite: true
# 93vbopgk1t-algo-1-tnbe6 | │         stopping_threshold: null
# 93vbopgk1t-algo-1-tnbe6 | │         divergence_threshold: null
# 93vbopgk1t-algo-1-tnbe6 | │         check_on_train_epoch_end: null
# 93vbopgk1t-algo-1-tnbe6 | │       model_summary:
# 93vbopgk1t-algo-1-tnbe6 | │         _target_: pytorch_lightning.callbacks.RichModelSummary
# 93vbopgk1t-algo-1-tnbe6 | │         max_depth: -1
# 93vbopgk1t-algo-1-tnbe6 | │       tqdm_progress_bar:
# 93vbopgk1t-algo-1-tnbe6 | │         _target_: pytorch_lightning.callbacks.TQDMProgressBar
# 93vbopgk1t-algo-1-tnbe6 | │         refresh_rate: 1
# 93vbopgk1t-algo-1-tnbe6 | │
# 93vbopgk1t-algo-1-tnbe6 | ├── logger
# 93vbopgk1t-algo-1-tnbe6 | │   └── tensorboard:
# 93vbopgk1t-algo-1-tnbe6 | │         _target_: pytorch_lightning.loggers.tensorboard.TensorBoardLogger
# 93vbopgk1t-algo-1-tnbe6 | │         save_dir: !!python/object/apply:pathlib.PosixPath
# 93vbopgk1t-algo-1-tnbe6 | │         - /
# 93vbopgk1t-algo-1-tnbe6 | │         - opt
# 93vbopgk1t-algo-1-tnbe6 | │         - ml
# 93vbopgk1t-algo-1-tnbe6 | │         - output
# 93vbopgk1t-algo-1-tnbe6 | │         - tensorboard
# 93vbopgk1t-algo-1-tnbe6 | │         - pipeline-scene
# 93vbopgk1t-algo-1-tnbe6 | │         - training-scene-pipeline-2023-02-05-14-39-40-522
# 93vbopgk1t-algo-1-tnbe6 | │         name: null
# 93vbopgk1t-algo-1-tnbe6 | │         log_graph: false
# 93vbopgk1t-algo-1-tnbe6 | │         default_hp_metric: true
# 93vbopgk1t-algo-1-tnbe6 | │         prefix: ''
# 93vbopgk1t-algo-1-tnbe6 | │
# 93vbopgk1t-algo-1-tnbe6 | ├── trainer
# 93vbopgk1t-algo-1-tnbe6 | │   └── _target_: pytorch_lightning.Trainer
# 93vbopgk1t-algo-1-tnbe6 | │       default_root_dir: /opt/ml/code/logs/train/runs/2023-02-05_14-40-32
# 93vbopgk1t-algo-1-tnbe6 | │       min_epochs: 5
# 93vbopgk1t-algo-1-tnbe6 | │       max_epochs: 10
# 93vbopgk1t-algo-1-tnbe6 | │       accelerator: auto
# 93vbopgk1t-algo-1-tnbe6 | │       devices: 1
# 93vbopgk1t-algo-1-tnbe6 | │       check_val_every_n_epoch: 1
# 93vbopgk1t-algo-1-tnbe6 | │       deterministic: false
# 93vbopgk1t-algo-1-tnbe6 | │       auto_lr_find: false
# 93vbopgk1t-algo-1-tnbe6 | │
# 93vbopgk1t-algo-1-tnbe6 | ├── paths
# 93vbopgk1t-algo-1-tnbe6 | │   └── root_dir: /opt/ml/code
# 93vbopgk1t-algo-1-tnbe6 | │       data_dir: /opt/ml/code/data/
# 93vbopgk1t-algo-1-tnbe6 | │       log_dir: /opt/ml/code/logs/
# 93vbopgk1t-algo-1-tnbe6 | │       output_dir: /opt/ml/code/logs/train/runs/2023-02-05_14-40-32
# 93vbopgk1t-algo-1-tnbe6 | │       work_dir: /opt/ml/code
# 93vbopgk1t-algo-1-tnbe6 | │
# 93vbopgk1t-algo-1-tnbe6 | ├── extras
# 93vbopgk1t-algo-1-tnbe6 | │   └── ignore_warnings: false
# 93vbopgk1t-algo-1-tnbe6 | │       enforce_tags: true
# 93vbopgk1t-algo-1-tnbe6 | │       print_config: true
# 93vbopgk1t-algo-1-tnbe6 | │
# 93vbopgk1t-algo-1-tnbe6 | ├── task_name
# 93vbopgk1t-algo-1-tnbe6 | │   └── train
# 93vbopgk1t-algo-1-tnbe6 | ├── tags
# 93vbopgk1t-algo-1-tnbe6 | │   └── ['Intel Scene Classification Training']
# 93vbopgk1t-algo-1-tnbe6 | ├── train
# 93vbopgk1t-algo-1-tnbe6 | │   └── True
# 93vbopgk1t-algo-1-tnbe6 | ├── test
# 93vbopgk1t-algo-1-tnbe6 | │   └── True
# 93vbopgk1t-algo-1-tnbe6 | ├── ckpt_path
# 93vbopgk1t-algo-1-tnbe6 | │   └── None
# 93vbopgk1t-algo-1-tnbe6 | ├── seed
# 93vbopgk1t-algo-1-tnbe6 | │   └── 12345
# 93vbopgk1t-algo-1-tnbe6 | ├── script
# 93vbopgk1t-algo-1-tnbe6 | │   └── True
# 93vbopgk1t-algo-1-tnbe6 | └── trace
# 93vbopgk1t-algo-1-tnbe6 |     └── None
# 93vbopgk1t-algo-1-tnbe6 | Global seed set to 12345
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:32,832][src.train][INFO] - Instantiating datamodule <src.data.intel_scene_datamodule.IntelSceneDataModule>
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:33,432][src.train][INFO] - Instantiating model <src.models.timm_module.Timm_LitModule>
# 93vbopgk1t-algo-1-tnbe6 | ERROR: ld.so: object '/libchangehostname.so' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# 93vbopgk1t-algo-1-tnbe6 | ERROR: ld.so: object '/libchangehostname.so' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:33,733][matplotlib.font_manager][INFO] - generated new fontManager
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:34,581][timm.models.helpers][INFO] - Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/spnasnet_100-048bc3f4.pth)
# 93vbopgk1t-algo-1-tnbe6 | Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/spnasnet_100-048bc3f4.pth" to /root/.cache/torch/hub/checkpoints/spnasnet_100-048bc3f4.pth
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:35,281][src.train][INFO] - Instantiating callbacks...
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:35,282][src.utils.utils][INFO] - Instantiating callback <pytorch_lightning.callbacks.ModelCheckpoint>
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:35,285][src.utils.utils][INFO] - Instantiating callback <pytorch_lightning.callbacks.EarlyStopping>
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:35,287][src.utils.utils][INFO] - Instantiating callback <pytorch_lightning.callbacks.RichModelSummary>
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:35,288][src.utils.utils][INFO] - Instantiating callback <pytorch_lightning.callbacks.TQDMProgressBar>
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:35,289][src.train][INFO] - Instantiating loggers...
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:35,289][src.utils.utils][INFO] - Instantiating logger <pytorch_lightning.loggers.tensorboard.TensorBoardLogger>
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:35,290][src.train][INFO] - Instantiating trainer <pytorch_lightning.Trainer>
# 93vbopgk1t-algo-1-tnbe6 | Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# 93vbopgk1t-algo-1-tnbe6 | GPU available: False, used: False
# 93vbopgk1t-algo-1-tnbe6 | TPU available: False, using: 0 TPU cores
# 93vbopgk1t-algo-1-tnbe6 | IPU available: False, using: 0 IPUs
# 93vbopgk1t-algo-1-tnbe6 | HPU available: False, using: 0 HPUs
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:35,342][src.train][INFO] - Logging hyperparameters!
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:35,356][src.train][INFO] - Starting training!
# 93vbopgk1t-algo-1-tnbe6 | ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# 93vbopgk1t-algo-1-tnbe6 | ┃     ┃ Name                     ┃ Type                   ┃ Params ┃
# 93vbopgk1t-algo-1-tnbe6 | ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# 93vbopgk1t-algo-1-tnbe6 | │ 0   │ net                      │ EfficientNet           │  3.1 M │
# 93vbopgk1t-algo-1-tnbe6 | │ 1   │ net.conv_stem            │ Conv2d                 │    864 │
# 93vbopgk1t-algo-1-tnbe6 | │ 2   │ net.bn1                  │ BatchNormAct2d         │     64 │
# 93vbopgk1t-algo-1-tnbe6 | │ 3   │ net.bn1.drop             │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 4   │ net.bn1.act              │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 5   │ net.blocks               │ Sequential             │  2.7 M │
# 93vbopgk1t-algo-1-tnbe6 | │ 6   │ net.blocks.0             │ Sequential             │    896 │
# 93vbopgk1t-algo-1-tnbe6 | │ 7   │ net.blocks.0.0           │ DepthwiseSeparableConv │    896 │
# 93vbopgk1t-algo-1-tnbe6 | │ 8   │ net.blocks.0.0.conv_dw   │ Conv2d                 │    288 │
# 93vbopgk1t-algo-1-tnbe6 | │ 9   │ net.blocks.0.0.bn1       │ BatchNormAct2d         │     64 │
# 93vbopgk1t-algo-1-tnbe6 | │ 10  │ net.blocks.0.0.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 11  │ net.blocks.0.0.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 12  │ net.blocks.0.0.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 13  │ net.blocks.0.0.conv_pw   │ Conv2d                 │    512 │
# 93vbopgk1t-algo-1-tnbe6 | │ 14  │ net.blocks.0.0.bn2       │ BatchNormAct2d         │     32 │
# 93vbopgk1t-algo-1-tnbe6 | │ 15  │ net.blocks.0.0.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 16  │ net.blocks.0.0.bn2.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 17  │ net.blocks.0.0.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 18  │ net.blocks.1             │ Sequential             │ 11.5 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 19  │ net.blocks.1.0           │ InvertedResidual       │  2.6 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 20  │ net.blocks.1.0.conv_pw   │ Conv2d                 │    768 │
# 93vbopgk1t-algo-1-tnbe6 | │ 21  │ net.blocks.1.0.bn1       │ BatchNormAct2d         │     96 │
# 93vbopgk1t-algo-1-tnbe6 | │ 22  │ net.blocks.1.0.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 23  │ net.blocks.1.0.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 24  │ net.blocks.1.0.conv_dw   │ Conv2d                 │    432 │
# 93vbopgk1t-algo-1-tnbe6 | │ 25  │ net.blocks.1.0.bn2       │ BatchNormAct2d         │     96 │
# 93vbopgk1t-algo-1-tnbe6 | │ 26  │ net.blocks.1.0.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 27  │ net.blocks.1.0.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 28  │ net.blocks.1.0.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 29  │ net.blocks.1.0.conv_pwl  │ Conv2d                 │  1.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 30  │ net.blocks.1.0.bn3       │ BatchNormAct2d         │     48 │
# 93vbopgk1t-algo-1-tnbe6 | │ 31  │ net.blocks.1.0.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 32  │ net.blocks.1.0.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 33  │ net.blocks.1.0.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 34  │ net.blocks.1.1           │ InvertedResidual       │  4.4 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 35  │ net.blocks.1.1.conv_pw   │ Conv2d                 │  1.7 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 36  │ net.blocks.1.1.bn1       │ BatchNormAct2d         │    144 │
# 93vbopgk1t-algo-1-tnbe6 | │ 37  │ net.blocks.1.1.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 38  │ net.blocks.1.1.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 39  │ net.blocks.1.1.conv_dw   │ Conv2d                 │    648 │
# 93vbopgk1t-algo-1-tnbe6 | │ 40  │ net.blocks.1.1.bn2       │ BatchNormAct2d         │    144 │
# 93vbopgk1t-algo-1-tnbe6 | │ 41  │ net.blocks.1.1.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 42  │ net.blocks.1.1.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 43  │ net.blocks.1.1.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 44  │ net.blocks.1.1.conv_pwl  │ Conv2d                 │  1.7 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 45  │ net.blocks.1.1.bn3       │ BatchNormAct2d         │     48 │
# 93vbopgk1t-algo-1-tnbe6 | │ 46  │ net.blocks.1.1.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 47  │ net.blocks.1.1.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 48  │ net.blocks.1.1.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 49  │ net.blocks.1.2           │ InvertedResidual       │  4.4 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 50  │ net.blocks.1.2.conv_pw   │ Conv2d                 │  1.7 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 51  │ net.blocks.1.2.bn1       │ BatchNormAct2d         │    144 │
# 93vbopgk1t-algo-1-tnbe6 | │ 52  │ net.blocks.1.2.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 53  │ net.blocks.1.2.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 54  │ net.blocks.1.2.conv_dw   │ Conv2d                 │    648 │
# 93vbopgk1t-algo-1-tnbe6 | │ 55  │ net.blocks.1.2.bn2       │ BatchNormAct2d         │    144 │
# 93vbopgk1t-algo-1-tnbe6 | │ 56  │ net.blocks.1.2.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 57  │ net.blocks.1.2.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 58  │ net.blocks.1.2.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 59  │ net.blocks.1.2.conv_pwl  │ Conv2d                 │  1.7 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 60  │ net.blocks.1.2.bn3       │ BatchNormAct2d         │     48 │
# 93vbopgk1t-algo-1-tnbe6 | │ 61  │ net.blocks.1.2.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 62  │ net.blocks.1.2.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 63  │ net.blocks.1.2.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 64  │ net.blocks.2             │ Sequential             │ 47.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 65  │ net.blocks.2.0           │ InvertedResidual       │ 13.5 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 66  │ net.blocks.2.0.conv_pw   │ Conv2d                 │  3.5 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 67  │ net.blocks.2.0.bn1       │ BatchNormAct2d         │    288 │
# 93vbopgk1t-algo-1-tnbe6 | │ 68  │ net.blocks.2.0.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 69  │ net.blocks.2.0.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 70  │ net.blocks.2.0.conv_dw   │ Conv2d                 │  3.6 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 71  │ net.blocks.2.0.bn2       │ BatchNormAct2d         │    288 │
# 93vbopgk1t-algo-1-tnbe6 | │ 72  │ net.blocks.2.0.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 73  │ net.blocks.2.0.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 74  │ net.blocks.2.0.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 75  │ net.blocks.2.0.conv_pwl  │ Conv2d                 │  5.8 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 76  │ net.blocks.2.0.bn3       │ BatchNormAct2d         │     80 │
# 93vbopgk1t-algo-1-tnbe6 | │ 77  │ net.blocks.2.0.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 78  │ net.blocks.2.0.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 79  │ net.blocks.2.0.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 80  │ net.blocks.2.1           │ InvertedResidual       │ 11.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 81  │ net.blocks.2.1.conv_pw   │ Conv2d                 │  4.8 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 82  │ net.blocks.2.1.bn1       │ BatchNormAct2d         │    240 │
# 93vbopgk1t-algo-1-tnbe6 | │ 83  │ net.blocks.2.1.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 84  │ net.blocks.2.1.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 85  │ net.blocks.2.1.conv_dw   │ Conv2d                 │  1.1 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 86  │ net.blocks.2.1.bn2       │ BatchNormAct2d         │    240 │
# 93vbopgk1t-algo-1-tnbe6 | │ 87  │ net.blocks.2.1.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 88  │ net.blocks.2.1.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 89  │ net.blocks.2.1.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 90  │ net.blocks.2.1.conv_pwl  │ Conv2d                 │  4.8 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 91  │ net.blocks.2.1.bn3       │ BatchNormAct2d         │     80 │
# 93vbopgk1t-algo-1-tnbe6 | │ 92  │ net.blocks.2.1.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 93  │ net.blocks.2.1.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 94  │ net.blocks.2.1.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 95  │ net.blocks.2.2           │ InvertedResidual       │ 11.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 96  │ net.blocks.2.2.conv_pw   │ Conv2d                 │  4.8 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 97  │ net.blocks.2.2.bn1       │ BatchNormAct2d         │    240 │
# 93vbopgk1t-algo-1-tnbe6 | │ 98  │ net.blocks.2.2.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 99  │ net.blocks.2.2.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 100 │ net.blocks.2.2.conv_dw   │ Conv2d                 │  1.1 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 101 │ net.blocks.2.2.bn2       │ BatchNormAct2d         │    240 │
# 93vbopgk1t-algo-1-tnbe6 | │ 102 │ net.blocks.2.2.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 103 │ net.blocks.2.2.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 104 │ net.blocks.2.2.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 105 │ net.blocks.2.2.conv_pwl  │ Conv2d                 │  4.8 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 106 │ net.blocks.2.2.bn3       │ BatchNormAct2d         │     80 │
# 93vbopgk1t-algo-1-tnbe6 | │ 107 │ net.blocks.2.2.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 108 │ net.blocks.2.2.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 109 │ net.blocks.2.2.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 110 │ net.blocks.2.3           │ InvertedResidual       │ 11.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 111 │ net.blocks.2.3.conv_pw   │ Conv2d                 │  4.8 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 112 │ net.blocks.2.3.bn1       │ BatchNormAct2d         │    240 │
# 93vbopgk1t-algo-1-tnbe6 | │ 113 │ net.blocks.2.3.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 114 │ net.blocks.2.3.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 115 │ net.blocks.2.3.conv_dw   │ Conv2d                 │  1.1 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 116 │ net.blocks.2.3.bn2       │ BatchNormAct2d         │    240 │
# 93vbopgk1t-algo-1-tnbe6 | │ 117 │ net.blocks.2.3.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 118 │ net.blocks.2.3.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 119 │ net.blocks.2.3.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 120 │ net.blocks.2.3.conv_pwl  │ Conv2d                 │  4.8 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 121 │ net.blocks.2.3.bn3       │ BatchNormAct2d         │     80 │
# 93vbopgk1t-algo-1-tnbe6 | │ 122 │ net.blocks.2.3.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 123 │ net.blocks.2.3.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 124 │ net.blocks.2.3.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 125 │ net.blocks.3             │ Sequential             │  160 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 126 │ net.blocks.3.0           │ InvertedResidual       │ 35.9 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 127 │ net.blocks.3.0.conv_pw   │ Conv2d                 │  9.6 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 128 │ net.blocks.3.0.bn1       │ BatchNormAct2d         │    480 │
# 93vbopgk1t-algo-1-tnbe6 | │ 129 │ net.blocks.3.0.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 130 │ net.blocks.3.0.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 131 │ net.blocks.3.0.conv_dw   │ Conv2d                 │  6.0 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 132 │ net.blocks.3.0.bn2       │ BatchNormAct2d         │    480 │
# 93vbopgk1t-algo-1-tnbe6 | │ 133 │ net.blocks.3.0.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 134 │ net.blocks.3.0.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 135 │ net.blocks.3.0.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 136 │ net.blocks.3.0.conv_pwl  │ Conv2d                 │ 19.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 137 │ net.blocks.3.0.bn3       │ BatchNormAct2d         │    160 │
# 93vbopgk1t-algo-1-tnbe6 | │ 138 │ net.blocks.3.0.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 139 │ net.blocks.3.0.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 140 │ net.blocks.3.0.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 141 │ net.blocks.3.1           │ InvertedResidual       │ 41.7 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 142 │ net.blocks.3.1.conv_pw   │ Conv2d                 │ 19.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 143 │ net.blocks.3.1.bn1       │ BatchNormAct2d         │    480 │
# 93vbopgk1t-algo-1-tnbe6 | │ 144 │ net.blocks.3.1.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 145 │ net.blocks.3.1.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 146 │ net.blocks.3.1.conv_dw   │ Conv2d                 │  2.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 147 │ net.blocks.3.1.bn2       │ BatchNormAct2d         │    480 │
# 93vbopgk1t-algo-1-tnbe6 | │ 148 │ net.blocks.3.1.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 149 │ net.blocks.3.1.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 150 │ net.blocks.3.1.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 151 │ net.blocks.3.1.conv_pwl  │ Conv2d                 │ 19.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 152 │ net.blocks.3.1.bn3       │ BatchNormAct2d         │    160 │
# 93vbopgk1t-algo-1-tnbe6 | │ 153 │ net.blocks.3.1.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 154 │ net.blocks.3.1.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 155 │ net.blocks.3.1.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 156 │ net.blocks.3.2           │ InvertedResidual       │ 41.7 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 157 │ net.blocks.3.2.conv_pw   │ Conv2d                 │ 19.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 158 │ net.blocks.3.2.bn1       │ BatchNormAct2d         │    480 │
# 93vbopgk1t-algo-1-tnbe6 | │ 159 │ net.blocks.3.2.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 160 │ net.blocks.3.2.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 161 │ net.blocks.3.2.conv_dw   │ Conv2d                 │  2.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 162 │ net.blocks.3.2.bn2       │ BatchNormAct2d         │    480 │
# 93vbopgk1t-algo-1-tnbe6 | │ 163 │ net.blocks.3.2.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 164 │ net.blocks.3.2.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 165 │ net.blocks.3.2.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 166 │ net.blocks.3.2.conv_pwl  │ Conv2d                 │ 19.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 167 │ net.blocks.3.2.bn3       │ BatchNormAct2d         │    160 │
# 93vbopgk1t-algo-1-tnbe6 | │ 168 │ net.blocks.3.2.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 169 │ net.blocks.3.2.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 170 │ net.blocks.3.2.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 171 │ net.blocks.3.3           │ InvertedResidual       │ 41.7 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 172 │ net.blocks.3.3.conv_pw   │ Conv2d                 │ 19.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 173 │ net.blocks.3.3.bn1       │ BatchNormAct2d         │    480 │
# 93vbopgk1t-algo-1-tnbe6 | │ 174 │ net.blocks.3.3.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 175 │ net.blocks.3.3.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 176 │ net.blocks.3.3.conv_dw   │ Conv2d                 │  2.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 177 │ net.blocks.3.3.bn2       │ BatchNormAct2d         │    480 │
# 93vbopgk1t-algo-1-tnbe6 | │ 178 │ net.blocks.3.3.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 179 │ net.blocks.3.3.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 180 │ net.blocks.3.3.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 181 │ net.blocks.3.3.conv_pwl  │ Conv2d                 │ 19.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 182 │ net.blocks.3.3.bn3       │ BatchNormAct2d         │    160 │
# 93vbopgk1t-algo-1-tnbe6 | │ 183 │ net.blocks.3.3.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 184 │ net.blocks.3.3.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 185 │ net.blocks.3.3.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 186 │ net.blocks.4             │ Sequential             │  290 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 187 │ net.blocks.4.0           │ InvertedResidual       │ 98.6 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 188 │ net.blocks.4.0.conv_pw   │ Conv2d                 │ 38.4 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 189 │ net.blocks.4.0.bn1       │ BatchNormAct2d         │    960 │
# 93vbopgk1t-algo-1-tnbe6 | │ 190 │ net.blocks.4.0.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 191 │ net.blocks.4.0.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 192 │ net.blocks.4.0.conv_dw   │ Conv2d                 │ 12.0 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 193 │ net.blocks.4.0.bn2       │ BatchNormAct2d         │    960 │
# 93vbopgk1t-algo-1-tnbe6 | │ 194 │ net.blocks.4.0.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 195 │ net.blocks.4.0.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 196 │ net.blocks.4.0.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 197 │ net.blocks.4.0.conv_pwl  │ Conv2d                 │ 46.1 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 198 │ net.blocks.4.0.bn3       │ BatchNormAct2d         │    192 │
# 93vbopgk1t-algo-1-tnbe6 | │ 199 │ net.blocks.4.0.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 200 │ net.blocks.4.0.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 201 │ net.blocks.4.0.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 202 │ net.blocks.4.1           │ InvertedResidual       │ 63.8 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 203 │ net.blocks.4.1.conv_pw   │ Conv2d                 │ 27.6 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 204 │ net.blocks.4.1.bn1       │ BatchNormAct2d         │    576 │
# 93vbopgk1t-algo-1-tnbe6 | │ 205 │ net.blocks.4.1.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 206 │ net.blocks.4.1.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 207 │ net.blocks.4.1.conv_dw   │ Conv2d                 │  7.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 208 │ net.blocks.4.1.bn2       │ BatchNormAct2d         │    576 │
# 93vbopgk1t-algo-1-tnbe6 | │ 209 │ net.blocks.4.1.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 210 │ net.blocks.4.1.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 211 │ net.blocks.4.1.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 212 │ net.blocks.4.1.conv_pwl  │ Conv2d                 │ 27.6 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 213 │ net.blocks.4.1.bn3       │ BatchNormAct2d         │    192 │
# 93vbopgk1t-algo-1-tnbe6 | │ 214 │ net.blocks.4.1.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 215 │ net.blocks.4.1.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 216 │ net.blocks.4.1.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 217 │ net.blocks.4.2           │ InvertedResidual       │ 63.8 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 218 │ net.blocks.4.2.conv_pw   │ Conv2d                 │ 27.6 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 219 │ net.blocks.4.2.bn1       │ BatchNormAct2d         │    576 │
# 93vbopgk1t-algo-1-tnbe6 | │ 220 │ net.blocks.4.2.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 221 │ net.blocks.4.2.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 222 │ net.blocks.4.2.conv_dw   │ Conv2d                 │  7.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 223 │ net.blocks.4.2.bn2       │ BatchNormAct2d         │    576 │
# 93vbopgk1t-algo-1-tnbe6 | │ 224 │ net.blocks.4.2.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 225 │ net.blocks.4.2.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 226 │ net.blocks.4.2.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 227 │ net.blocks.4.2.conv_pwl  │ Conv2d                 │ 27.6 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 228 │ net.blocks.4.2.bn3       │ BatchNormAct2d         │    192 │
# 93vbopgk1t-algo-1-tnbe6 | │ 229 │ net.blocks.4.2.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 230 │ net.blocks.4.2.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 231 │ net.blocks.4.2.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 232 │ net.blocks.4.3           │ InvertedResidual       │ 63.8 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 233 │ net.blocks.4.3.conv_pw   │ Conv2d                 │ 27.6 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 234 │ net.blocks.4.3.bn1       │ BatchNormAct2d         │    576 │
# 93vbopgk1t-algo-1-tnbe6 | │ 235 │ net.blocks.4.3.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 236 │ net.blocks.4.3.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 237 │ net.blocks.4.3.conv_dw   │ Conv2d                 │  7.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 238 │ net.blocks.4.3.bn2       │ BatchNormAct2d         │    576 │
# 93vbopgk1t-algo-1-tnbe6 | │ 239 │ net.blocks.4.3.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 240 │ net.blocks.4.3.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 241 │ net.blocks.4.3.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 242 │ net.blocks.4.3.conv_pwl  │ Conv2d                 │ 27.6 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 243 │ net.blocks.4.3.bn3       │ BatchNormAct2d         │    192 │
# 93vbopgk1t-algo-1-tnbe6 | │ 244 │ net.blocks.4.3.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 245 │ net.blocks.4.3.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 246 │ net.blocks.4.3.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 247 │ net.blocks.5             │ Sequential             │  1.6 M │
# 93vbopgk1t-algo-1-tnbe6 | │ 248 │ net.blocks.5.0           │ InvertedResidual       │  182 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 249 │ net.blocks.5.0.conv_pw   │ Conv2d                 │ 55.3 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 250 │ net.blocks.5.0.bn1       │ BatchNormAct2d         │  1.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 251 │ net.blocks.5.0.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 252 │ net.blocks.5.0.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 253 │ net.blocks.5.0.conv_dw   │ Conv2d                 │ 14.4 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 254 │ net.blocks.5.0.bn2       │ BatchNormAct2d         │  1.2 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 255 │ net.blocks.5.0.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 256 │ net.blocks.5.0.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 257 │ net.blocks.5.0.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 258 │ net.blocks.5.0.conv_pwl  │ Conv2d                 │  110 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 259 │ net.blocks.5.0.bn3       │ BatchNormAct2d         │    384 │
# 93vbopgk1t-algo-1-tnbe6 | │ 260 │ net.blocks.5.0.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 261 │ net.blocks.5.0.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 262 │ net.blocks.5.0.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 263 │ net.blocks.5.1           │ InvertedResidual       │  476 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 264 │ net.blocks.5.1.conv_pw   │ Conv2d                 │  221 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 265 │ net.blocks.5.1.bn1       │ BatchNormAct2d         │  2.3 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 266 │ net.blocks.5.1.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 267 │ net.blocks.5.1.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 268 │ net.blocks.5.1.conv_dw   │ Conv2d                 │ 28.8 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 269 │ net.blocks.5.1.bn2       │ BatchNormAct2d         │  2.3 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 270 │ net.blocks.5.1.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 271 │ net.blocks.5.1.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 272 │ net.blocks.5.1.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 273 │ net.blocks.5.1.conv_pwl  │ Conv2d                 │  221 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 274 │ net.blocks.5.1.bn3       │ BatchNormAct2d         │    384 │
# 93vbopgk1t-algo-1-tnbe6 | │ 275 │ net.blocks.5.1.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 276 │ net.blocks.5.1.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 277 │ net.blocks.5.1.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 278 │ net.blocks.5.2           │ InvertedResidual       │  476 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 279 │ net.blocks.5.2.conv_pw   │ Conv2d                 │  221 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 280 │ net.blocks.5.2.bn1       │ BatchNormAct2d         │  2.3 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 281 │ net.blocks.5.2.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 282 │ net.blocks.5.2.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 283 │ net.blocks.5.2.conv_dw   │ Conv2d                 │ 28.8 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 284 │ net.blocks.5.2.bn2       │ BatchNormAct2d         │  2.3 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 285 │ net.blocks.5.2.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 286 │ net.blocks.5.2.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 287 │ net.blocks.5.2.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 288 │ net.blocks.5.2.conv_pwl  │ Conv2d                 │  221 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 289 │ net.blocks.5.2.bn3       │ BatchNormAct2d         │    384 │
# 93vbopgk1t-algo-1-tnbe6 | │ 290 │ net.blocks.5.2.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 291 │ net.blocks.5.2.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 292 │ net.blocks.5.2.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 293 │ net.blocks.5.3           │ InvertedResidual       │  476 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 294 │ net.blocks.5.3.conv_pw   │ Conv2d                 │  221 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 295 │ net.blocks.5.3.bn1       │ BatchNormAct2d         │  2.3 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 296 │ net.blocks.5.3.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 297 │ net.blocks.5.3.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 298 │ net.blocks.5.3.conv_dw   │ Conv2d                 │ 28.8 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 299 │ net.blocks.5.3.bn2       │ BatchNormAct2d         │  2.3 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 300 │ net.blocks.5.3.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 301 │ net.blocks.5.3.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 302 │ net.blocks.5.3.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 303 │ net.blocks.5.3.conv_pwl  │ Conv2d                 │  221 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 304 │ net.blocks.5.3.bn3       │ BatchNormAct2d         │    384 │
# 93vbopgk1t-algo-1-tnbe6 | │ 305 │ net.blocks.5.3.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 306 │ net.blocks.5.3.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 307 │ net.blocks.5.3.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 308 │ net.blocks.6             │ Sequential             │  605 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 309 │ net.blocks.6.0           │ InvertedResidual       │  605 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 310 │ net.blocks.6.0.conv_pw   │ Conv2d                 │  221 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 311 │ net.blocks.6.0.bn1       │ BatchNormAct2d         │  2.3 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 312 │ net.blocks.6.0.bn1.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 313 │ net.blocks.6.0.bn1.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 314 │ net.blocks.6.0.conv_dw   │ Conv2d                 │ 10.4 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 315 │ net.blocks.6.0.bn2       │ BatchNormAct2d         │  2.3 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 316 │ net.blocks.6.0.bn2.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 317 │ net.blocks.6.0.bn2.act   │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 318 │ net.blocks.6.0.se        │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 319 │ net.blocks.6.0.conv_pwl  │ Conv2d                 │  368 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 320 │ net.blocks.6.0.bn3       │ BatchNormAct2d         │    640 │
# 93vbopgk1t-algo-1-tnbe6 | │ 321 │ net.blocks.6.0.bn3.drop  │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 322 │ net.blocks.6.0.bn3.act   │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 323 │ net.blocks.6.0.drop_path │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 324 │ net.conv_head            │ Conv2d                 │  409 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 325 │ net.bn2                  │ BatchNormAct2d         │  2.6 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 326 │ net.bn2.drop             │ Identity               │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 327 │ net.bn2.act              │ ReLU                   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 328 │ net.global_pool          │ SelectAdaptivePool2d   │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 329 │ net.global_pool.flatten  │ Flatten                │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 330 │ net.global_pool.pool     │ AdaptiveAvgPool2d      │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 331 │ net.classifier           │ Linear                 │  7.7 K │
# 93vbopgk1t-algo-1-tnbe6 | │ 332 │ criterion                │ CrossEntropyLoss       │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 333 │ train_acc                │ MulticlassAccuracy     │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 334 │ val_acc                  │ MulticlassAccuracy     │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 335 │ test_acc                 │ MulticlassAccuracy     │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 336 │ train_loss               │ MeanMetric             │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 337 │ val_loss                 │ MeanMetric             │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 338 │ test_loss                │ MeanMetric             │      0 │
# 93vbopgk1t-algo-1-tnbe6 | │ 339 │ val_acc_best             │ MaxMetric              │      0 │
# 93vbopgk1t-algo-1-tnbe6 | └─────┴──────────────────────────┴────────────────────────┴────────┘
# 93vbopgk1t-algo-1-tnbe6 | Trainable params: 3.1 M
# 93vbopgk1t-algo-1-tnbe6 | Non-trainable params: 0
# 93vbopgk1t-algo-1-tnbe6 | Total params: 3.1 M
# 93vbopgk1t-algo-1-tnbe6 | Total estimated model params size (MB): 12
# Sanity Checking: 0it [00:00, ?it/s]
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:35.829 19b0de12d60e:40 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# 93vbopgk1t-algo-1-tnbe6 | [2023-02-05 14:40:36.125 19b0de12d60e:40 INFO profiler_config_parser.py:111] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# 93vbopgk1t-algo-1-tnbe6 | Sanity Checking:   0%|          | 0/2 [00:00<?, ?it/s]
# 93vbopgk1t-algo-1-tnbe6 | Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# 93vbopgk1t-algo-1-tnbe6 | Sanity Checking DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  1.28s/it]
# 93vbopgk1t-algo-1-tnbe6 | Sanity Checking DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# 93vbopgk1t-algo-1-tnbe6 |
# 93vbopgk1t-algo-1-tnbe6 | /opt/conda/lib/python3.8/site-packages/pytorch_lightning/trainer/trainer.py:1558: PossibleUserWarning: The number of training batches (29) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# 93vbopgk1t-algo-1-tnbe6 |   rank_zero_warn(
# Training:   0%|          | 0/33 [00:00<?, ?it/s] [00:00, ?it/s]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:   0%|          | 0/33 [00:00<?, ?it/s]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:   3%|▎         | 1/33 [00:03<02:07,  4.00s/it]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:   3%|▎         | 1/33 [00:04<02:08,  4.00s/it, loss=12.4, v_num=0, train/loss_step=12.40, train/acc_step=0.000]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:   6%|▌         | 2/33 [00:06<01:48,  3.49s/it, loss=12.4, v_num=0, train/loss_step=12.40, train/acc_step=0.000]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:   6%|▌         | 2/33 [00:06<01:48,  3.49s/it, loss=11.7, v_num=0, train/loss_step=11.10, train/acc_step=0.000]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:   9%|▉         | 3/33 [00:09<01:33,  3.10s/it, loss=11.7, v_num=0, train/loss_step=11.10, train/acc_step=0.000]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:   9%|▉         | 3/33 [00:09<01:33,  3.10s/it, loss=11.6, v_num=0, train/loss_step=11.20, train/acc_step=0.125]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  12%|█▏        | 4/33 [00:11<01:23,  2.89s/it, loss=11.6, v_num=0, train/loss_step=11.20, train/acc_step=0.125]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  12%|█▏        | 4/33 [00:11<01:23,  2.89s/it, loss=11.3, v_num=0, train/loss_step=10.40, train/acc_step=0.000]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  15%|█▌        | 5/33 [00:14<01:18,  2.81s/it, loss=11.3, v_num=0, train/loss_step=10.40, train/acc_step=0.000]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  15%|█▌        | 5/33 [00:14<01:18,  2.81s/it, loss=11.3, v_num=0, train/loss_step=11.40, train/acc_step=0.0625]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  18%|█▊        | 6/33 [00:16<01:13,  2.74s/it, loss=11.3, v_num=0, train/loss_step=11.40, train/acc_step=0.0625]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  18%|█▊        | 6/33 [00:16<01:13,  2.74s/it, loss=11.3, v_num=0, train/loss_step=11.50, train/acc_step=0.000]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  21%|██        | 7/33 [00:18<01:09,  2.67s/it, loss=11.3, v_num=0, train/loss_step=11.50, train/acc_step=0.000]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  21%|██        | 7/33 [00:18<01:09,  2.67s/it, loss=11.1, v_num=0, train/loss_step=9.930, train/acc_step=0.125]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  24%|██▍       | 8/33 [00:20<01:05,  2.62s/it, loss=11.1, v_num=0, train/loss_step=9.930, train/acc_step=0.125]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  24%|██▍       | 8/33 [00:20<01:05,  2.62s/it, loss=11, v_num=0, train/loss_step=10.50, train/acc_step=0.000]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  27%|██▋       | 9/33 [00:23<01:01,  2.58s/it, loss=11, v_num=0, train/loss_step=10.50, train/acc_step=0.000]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  27%|██▋       | 9/33 [00:23<01:01,  2.58s/it, loss=11, v_num=0, train/loss_step=10.70, train/acc_step=0.0625]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  30%|███       | 10/33 [00:25<00:58,  2.55s/it, loss=11, v_num=0, train/loss_step=10.70, train/acc_step=0.0625]
# 93vbopgk1t-algo-1-tnbe6 | Epoch 0:  30%|███       | 10/33 [00:25<00:58,  2.55s/it, loss=11, v_num=0, train/loss_step=10.70, train/acc_step=0.0625]

# %%
step_train = TrainingStep(
    name="TrainSceneClassifier", step_args=estimator_step_args, cache_config=cache_config
)

# %%
step_train

# %% [markdown]
# ## Eval Step

# %%
from sagemaker.pytorch.processing import PyTorchProcessor

# %%
pytorch_processor = PyTorchProcessor(
    image_uri="441249477288.dkr.ecr.ap-south-1.amazonaws.com/sagemaker-training:latest",
    framework_version="1.11.0",
    py_version="py38",
    role=role,
    sagemaker_session=pipeline_session,
    # instance_type="ml.m5.4xlarge",
    instance_type="local",
    instance_count=1,
    base_job_name=f"{base_job_name}/eval-scene-classifier",
    env={
        # "BATCH_SIZE": batch_size,
        # "MODEL": model_name,
        "BATCH_SIZE": "16",
        "MODEL": "spnasnet_100",
    },
)

# %%
eval_step_args = pytorch_processor.run(
    code="pipelines/evaluate.py",
    source_dir="sagemaker-kidu",
    inputs=[
        ProcessingInput(
            # source=step_train.properties.ModelArtifacts.S3ModelArtifacts,
            source="s3://sagemaker-ap-south-1-441249477288/pipelines-7mypdpqubax8-TrainSceneClassifier-u9XudMzGTd/output/model.tar.gz",
            destination="/opt/ml/processing/model",
        ),
        ProcessingInput(
            # source=step_process.properties.ProcessingOutputConfig.Outputs["test"].S3Output.S3Uri,
            source="s3://sagemaker-ap-south-1-441249477288/pipeline-scene/preprocess-scene-dataset-2023-01-29-14-40-58-863/output/test/",
            destination="/opt/ml/processing/test",
        ),
        ProcessingInput(
            # source=step_process.properties.ProcessingOutputConfig.Outputs["train"].S3Output.S3Uri,
            source="s3://sagemaker-ap-south-1-441249477288/pipeline-scene/preprocess-scene-dataset-2023-01-29-14-40-58-863/output/test/",
            destination="/opt/ml/processing/train",
        ),
        ProcessingInput(
            source="s3://sagemaker-ap-south-1-441249477288/old-data/prediction/",
            destination="/opt/ml/processing/prediction",
        ),
    ],
    outputs=[
        ProcessingOutput(output_name="evaluation", source="/opt/ml/processing/evaluation"),
    ],
)
# Out:
# Job Name:  pipeline-scene/eval-scene-classifier-2023-02-05-16-17-46-293
# Inputs:  [{'InputName': 'input-1', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-ap-south-1-441249477288/pipelines-7mypdpqubax8-TrainSceneClassifier-u9XudMzGTd/output/model.tar.gz', 'LocalPath': '/opt/ml/processing/model', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'input-2', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-ap-south-1-441249477288/pipeline-scene/preprocess-scene-dataset-2023-01-29-14-40-58-863/output/test/', 'LocalPath': '/opt/ml/processing/test', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'input-3', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-ap-south-1-441249477288/pipeline-scene/preprocess-scene-dataset-2023-01-29-14-40-58-863/output/test/', 'LocalPath': '/opt/ml/processing/train', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'input-4', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-ap-south-1-441249477288/old-data/prediction/', 'LocalPath': '/opt/ml/processing/prediction', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'code', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-ap-south-1-441249477288/pipeline-scene/eval-scene-classifier-2023-02-05-16-17-46-293/source/sourcedir.tar.gz', 'LocalPath': '/opt/ml/processing/input/code/', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'entrypoint', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-ap-south-1-441249477288/pipeline-scene/eval-scene-classifier-2023-02-05-16-17-46-293/source/runproc.sh', 'LocalPath': '/opt/ml/processing/input/entrypoint', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'evaluation', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-ap-south-1-441249477288/pipeline-scene/eval-scene-classifier-2023-02-05-16-17-46-293/output/evaluation', 'LocalPath': '/opt/ml/processing/evaluation', 'S3UploadMode': 'EndOfJob'}}]
# Creating 8dlcz49luv-algo-1-yfx1t ...
# Creating 8dlcz49luv-algo-1-yfx1t ... done
# Attaching to 8dlcz49luv-algo-1-yfx1t
# 8dlcz49luv-algo-1-yfx1t | :: Evaluating Model
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:47,408][src.utils.utils][INFO] - Enforcing tags! <cfg.extras.enforce_tags=True>
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:47,417][src.utils.utils][INFO] - Printing config tree with Rich! <cfg.extras.print_config=True>
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:47,418][src.utils.rich_utils][WARNING] - Field 'callbacks' not found in config. Skipping 'callbacks' config printing...
# 8dlcz49luv-algo-1-yfx1t | CONFIG
# 8dlcz49luv-algo-1-yfx1t | ├── data
# 8dlcz49luv-algo-1-yfx1t | │   └── _target_: src.data.intel_scene_datamodule.IntelSceneDataModule
# 8dlcz49luv-algo-1-yfx1t | │       train_data_dir: !!python/object/apply:pathlib.PosixPath
# 8dlcz49luv-algo-1-yfx1t | │       - /
# 8dlcz49luv-algo-1-yfx1t | │       - opt
# 8dlcz49luv-algo-1-yfx1t | │       - ml
# 8dlcz49luv-algo-1-yfx1t | │       - processing
# 8dlcz49luv-algo-1-yfx1t | │       - train
# 8dlcz49luv-algo-1-yfx1t | │       test_data_dir: !!python/object/apply:pathlib.PosixPath
# 8dlcz49luv-algo-1-yfx1t | │       - /
# 8dlcz49luv-algo-1-yfx1t | │       - opt
# 8dlcz49luv-algo-1-yfx1t | │       - ml
# 8dlcz49luv-algo-1-yfx1t | │       - processing
# 8dlcz49luv-algo-1-yfx1t | │       - test
# 8dlcz49luv-algo-1-yfx1t | │       batch_size: 16
# 8dlcz49luv-algo-1-yfx1t | │       train_val_test_split:
# 8dlcz49luv-algo-1-yfx1t | │       - 13600
# 8dlcz49luv-algo-1-yfx1t | │       - 1700
# 8dlcz49luv-algo-1-yfx1t | │       - 1734
# 8dlcz49luv-algo-1-yfx1t | │       num_workers: 2
# 8dlcz49luv-algo-1-yfx1t | │       pin_memory: false
# 8dlcz49luv-algo-1-yfx1t | │       use_augmentation_pipeline: 1
# 8dlcz49luv-algo-1-yfx1t | │
# 8dlcz49luv-algo-1-yfx1t | ├── model
# 8dlcz49luv-algo-1-yfx1t | │   └── _target_: src.models.timm_module.Timm_LitModule
# 8dlcz49luv-algo-1-yfx1t | │       optimizer:
# 8dlcz49luv-algo-1-yfx1t | │         _target_: torch.optim.Adam
# 8dlcz49luv-algo-1-yfx1t | │         _partial_: true
# 8dlcz49luv-algo-1-yfx1t | │       scheduler:
# 8dlcz49luv-algo-1-yfx1t | │         _target_: torch.optim.lr_scheduler.OneCycleLR
# 8dlcz49luv-algo-1-yfx1t | │         _partial_: true
# 8dlcz49luv-algo-1-yfx1t | │         max_lr: 0.1
# 8dlcz49luv-algo-1-yfx1t | │         epochs: 10
# 8dlcz49luv-algo-1-yfx1t | │         steps_per_epoch: 425
# 8dlcz49luv-algo-1-yfx1t | │       net:
# 8dlcz49luv-algo-1-yfx1t | │         _target_: timm.models.create_model
# 8dlcz49luv-algo-1-yfx1t | │         model_name: spnasnet_100
# 8dlcz49luv-algo-1-yfx1t | │         pretrained: true
# 8dlcz49luv-algo-1-yfx1t | │         in_chans: 3
# 8dlcz49luv-algo-1-yfx1t | │         num_classes: 6
# 8dlcz49luv-algo-1-yfx1t | │       num_class: 6
# 8dlcz49luv-algo-1-yfx1t | │       learning_rate: 0.001
# 8dlcz49luv-algo-1-yfx1t | │
# 8dlcz49luv-algo-1-yfx1t | ├── logger
# 8dlcz49luv-algo-1-yfx1t | │   └── tensorboard:
# 8dlcz49luv-algo-1-yfx1t | │         _target_: pytorch_lightning.loggers.tensorboard.TensorBoardLogger
# 8dlcz49luv-algo-1-yfx1t | │         save_dir: /opt/ml/processing/input/code/logs/eval/runs/2023-02-05_16-1
# 8dlcz49luv-algo-1-yfx1t | │         name: null
# 8dlcz49luv-algo-1-yfx1t | │         log_graph: false
# 8dlcz49luv-algo-1-yfx1t | │         default_hp_metric: true
# 8dlcz49luv-algo-1-yfx1t | │         prefix: ''
# 8dlcz49luv-algo-1-yfx1t | │
# 8dlcz49luv-algo-1-yfx1t | ├── trainer
# 8dlcz49luv-algo-1-yfx1t | │   └── _target_: pytorch_lightning.Trainer
# 8dlcz49luv-algo-1-yfx1t | │       default_root_dir: /opt/ml/processing/input/code/logs/eval/runs/2023-02-0
# 8dlcz49luv-algo-1-yfx1t | │       min_epochs: 1
# 8dlcz49luv-algo-1-yfx1t | │       max_epochs: 10
# 8dlcz49luv-algo-1-yfx1t | │       accelerator: auto
# 8dlcz49luv-algo-1-yfx1t | │       devices: 1
# 8dlcz49luv-algo-1-yfx1t | │       check_val_every_n_epoch: 1
# 8dlcz49luv-algo-1-yfx1t | │       deterministic: false
# 8dlcz49luv-algo-1-yfx1t | │       auto_lr_find: false
# 8dlcz49luv-algo-1-yfx1t | │
# 8dlcz49luv-algo-1-yfx1t | ├── paths
# 8dlcz49luv-algo-1-yfx1t | │   └── root_dir: /opt/ml/processing/input/code
# 8dlcz49luv-algo-1-yfx1t | │       data_dir: /opt/ml/processing/input/code/data/
# 8dlcz49luv-algo-1-yfx1t | │       log_dir: /opt/ml/processing/input/code/logs/
# 8dlcz49luv-algo-1-yfx1t | │       output_dir: /opt/ml/processing/input/code/logs/eval/runs/2023-02-05_16-1
# 8dlcz49luv-algo-1-yfx1t | │       work_dir: /opt/ml/processing/input/code
# 8dlcz49luv-algo-1-yfx1t | │
# 8dlcz49luv-algo-1-yfx1t | ├── extras
# 8dlcz49luv-algo-1-yfx1t | │   └── ignore_warnings: false
# 8dlcz49luv-algo-1-yfx1t | │       enforce_tags: true
# 8dlcz49luv-algo-1-yfx1t | │       print_config: true
# 8dlcz49luv-algo-1-yfx1t | │
# 8dlcz49luv-algo-1-yfx1t | ├── task_name
# 8dlcz49luv-algo-1-yfx1t | │   └── eval
# 8dlcz49luv-algo-1-yfx1t | ├── tags
# 8dlcz49luv-algo-1-yfx1t | │   └── ['Intel Scene Classification Evaluation']
# 8dlcz49luv-algo-1-yfx1t | └── ckpt_path
# 8dlcz49luv-algo-1-yfx1t |     └── last.ckpt
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:47,472][src.eval][INFO] - Instantiating datamodule <src.data.intel_scene_datamodule.IntelSceneDataModule>
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:48,455][src.eval][INFO] - Instantiating model <src.models.timm_module.Timm_LitModule>
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:49,153][timm.models.helpers][INFO] - Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/spnasnet_100-048bc3f4.pth)
# 8dlcz49luv-algo-1-yfx1t | Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/spnasnet_100-048bc3f4.pth" to /root/.cache/torch/hub/checkpoints/spnasnet_100-048bc3f4.pth
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:52,966][src.eval][INFO] - Instantiating loggers...
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:52,968][src.utils.utils][INFO] - Instantiating logger <pytorch_lightning.loggers.tensorboard.TensorBoardLogger>
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:52,977][src.eval][INFO] - Instantiating trainer <pytorch_lightning.Trainer>
# 8dlcz49luv-algo-1-yfx1t | GPU available: False, used: False
# 8dlcz49luv-algo-1-yfx1t | TPU available: False, using: 0 TPU cores
# 8dlcz49luv-algo-1-yfx1t | IPU available: False, using: 0 IPUs
# 8dlcz49luv-algo-1-yfx1t | HPU available: False, using: 0 HPUs
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:53,134][src.eval][INFO] - Logging hyperparameters!
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:53,157][src.eval][INFO] - Starting testing!
# 8dlcz49luv-algo-1-yfx1t | Restoring states from the checkpoint path at last.ckpt
# 8dlcz49luv-algo-1-yfx1t | Loaded model weights from checkpoint at last.ckpt
# Testing: 0it [00:00, ?it/s][2023-02-05 16:18:53.838 ff72b63b5eda:8 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:54.032 ff72b63b5eda:8 INFO profiler_config_parser.py:111] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# Testing DataLoader 0: 100% 4/4 [00:04<00:00,  1.07s/it][2023-02-05 16:18:59,322][tensorboardX.summary][INFO] - Summary name Confusion matrix is illegal; using Confusion_matrix instead.
# Testing DataLoader 0: 100% 4/4 [00:04<00:00,  1.20s/it]
# 8dlcz49luv-algo-1-yfx1t | ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# 8dlcz49luv-algo-1-yfx1t | ┃        Test metric        ┃       DataLoader 0        ┃
# 8dlcz49luv-algo-1-yfx1t | ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# 8dlcz49luv-algo-1-yfx1t | │         hp_metric         │     0.460317462682724     │
# 8dlcz49luv-algo-1-yfx1t | │       test/F1_Score       │     0.460317462682724     │
# 8dlcz49luv-algo-1-yfx1t | │      test/Precision       │     0.460317462682724     │
# 8dlcz49luv-algo-1-yfx1t | │        test/Recall        │     0.460317462682724     │
# 8dlcz49luv-algo-1-yfx1t | │         test/acc          │     0.460317462682724     │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/00  │            7.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/01  │            3.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/02  │           11.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/03  │            3.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/04  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/05  │           13.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/10  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/11  │           22.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/12  ���            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/13  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/14  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/15  │            4.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/20  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/21  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/22  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/23  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/24  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/25  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/30  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/31  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/32  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/33  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/34  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/35  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/40  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/41  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/42  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/43  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/44  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/45  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/50  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/51  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/52  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/53  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/54  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │ test/confusion_matrix/55  │            0.0            │
# 8dlcz49luv-algo-1-yfx1t | │         test/loss         │     1.156432032585144     │
# 8dlcz49luv-algo-1-yfx1t | └───────────────────────────┴───────────────────────────┘
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:59,587][src.utils.utils][INFO] - Output dir: /opt/ml/processing/input/code/logs/eval/runs/2023-02-05_16-18-46
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:59,589][src.utils.utils][INFO] - Closing loggers...
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:59,590][__main__][INFO] - Running Model explanation
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:59,971][__main__][INFO] - Loaded Model: RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |   original_name=Timm_LitModule
# 8dlcz49luv-algo-1-yfx1t |   (net): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |     original_name=EfficientNet
# 8dlcz49luv-algo-1-yfx1t |     (conv_stem): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |     (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |       original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |       (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |       (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |     )
# 8dlcz49luv-algo-1-yfx1t |     (blocks): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |       original_name=Sequential
# 8dlcz49luv-algo-1-yfx1t |       (0): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |         original_name=Sequential
# 8dlcz49luv-algo-1-yfx1t |         (0): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=DepthwiseSeparableConv
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |       )
# 8dlcz49luv-algo-1-yfx1t |       (1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |         original_name=Sequential
# 8dlcz49luv-algo-1-yfx1t |         (0): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |       )
# 8dlcz49luv-algo-1-yfx1t |       (2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |         original_name=Sequential
# 8dlcz49luv-algo-1-yfx1t |         (0): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |       )
# 8dlcz49luv-algo-1-yfx1t |       (3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |         original_name=Sequential
# 8dlcz49luv-algo-1-yfx1t |         (0): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |       )
# 8dlcz49luv-algo-1-yfx1t |       (4): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |         original_name=Sequential
# 8dlcz49luv-algo-1-yfx1t |         (0): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |       )
# 8dlcz49luv-algo-1-yfx1t |       (5): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |         original_name=Sequential
# 8dlcz49luv-algo-1-yfx1t |         (0): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |         (3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |       )
# 8dlcz49luv-algo-1-yfx1t |       (6): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |         original_name=Sequential
# 8dlcz49luv-algo-1-yfx1t |         (0): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |           original_name=InvertedResidual
# 8dlcz49luv-algo-1-yfx1t |           (conv_pw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn1): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (conv_dw): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (se): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           (conv_pwl): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |           (bn3): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |             original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |             (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |             (act): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |           )
# 8dlcz49luv-algo-1-yfx1t |           (drop_path): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |         )
# 8dlcz49luv-algo-1-yfx1t |       )
# 8dlcz49luv-algo-1-yfx1t |     )
# 8dlcz49luv-algo-1-yfx1t |     (conv_head): RecursiveScriptModule(original_name=Conv2d)
# 8dlcz49luv-algo-1-yfx1t |     (bn2): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |       original_name=BatchNormAct2d
# 8dlcz49luv-algo-1-yfx1t |       (drop): RecursiveScriptModule(original_name=Identity)
# 8dlcz49luv-algo-1-yfx1t |       (act): RecursiveScriptModule(original_name=ReLU)
# 8dlcz49luv-algo-1-yfx1t |     )
# 8dlcz49luv-algo-1-yfx1t |     (global_pool): RecursiveScriptModule(
# 8dlcz49luv-algo-1-yfx1t |       original_name=SelectAdaptivePool2d
# 8dlcz49luv-algo-1-yfx1t |       (flatten): RecursiveScriptModule(original_name=Flatten)
# 8dlcz49luv-algo-1-yfx1t |       (pool): RecursiveScriptModule(original_name=AdaptiveAvgPool2d)
# 8dlcz49luv-algo-1-yfx1t |     )
# 8dlcz49luv-algo-1-yfx1t |     (classifier): RecursiveScriptModule(original_name=Linear)
# 8dlcz49luv-algo-1-yfx1t |   )
# 8dlcz49luv-algo-1-yfx1t |   (criterion): RecursiveScriptModule(original_name=CrossEntropyLoss)
# 8dlcz49luv-algo-1-yfx1t |   (train_acc): RecursiveScriptModule(original_name=MulticlassAccuracy)
# 8dlcz49luv-algo-1-yfx1t |   (val_acc): RecursiveScriptModule(original_name=MulticlassAccuracy)
# 8dlcz49luv-algo-1-yfx1t |   (test_acc): RecursiveScriptModule(original_name=MulticlassAccuracy)
# 8dlcz49luv-algo-1-yfx1t |   (train_loss): RecursiveScriptModule(original_name=MeanMetric)
# 8dlcz49luv-algo-1-yfx1t |   (val_loss): RecursiveScriptModule(original_name=MeanMetric)
# 8dlcz49luv-algo-1-yfx1t |   (test_loss): RecursiveScriptModule(original_name=MeanMetric)
# 8dlcz49luv-algo-1-yfx1t |   (val_acc_best): RecursiveScriptModule(original_name=MaxMetric)
# 8dlcz49luv-algo-1-yfx1t | )
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:18:59,981][__main__][INFO] - /opt/ml/processing/prediction/103.jpg
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:19:00,586][__main__][INFO] - Predicted: street (confidence = 0.4800716042518616, index = 5)
# 8dlcz49luv-algo-1-yfx1t | [2023-02-05 16:19:00,587][__main__][INFO] - Integrated Gradients :
# 8dlcz49luv-algo-1-yfx1t | /opt/ml/processing/input/entrypoint/runproc.sh: line 16:     8 Killed                  python pipelines/evaluate.py "$@"
# 8dlcz49luv-algo-1-yfx1t exited with code 137
# 137
# Aborting on container exit...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sagemaker/local/image.py in process(self, processing_inputs, processing_output_config, environment, processing_job_name)
#     165         try:
# --> 166             _stream_output(process)
#     167         except RuntimeError as e:
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sagemaker/local/image.py in _stream_output(process)
#     913     if exit_code != 0:
# --> 914         raise RuntimeError("Process exited with code: %s" % exit_code)
#     915
#
# RuntimeError: Process exited with code: 137
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_15038/3289736851.py in <module>
#      24     ],
#      25     outputs=[
# ---> 26         ProcessingOutput(output_name="evaluation", source="/opt/ml/processing/evaluation"),
#      27     ],
#      28 )
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sagemaker/processing.py in run(self, code, source_dir, dependencies, git_config, inputs, outputs, arguments, wait, logs, job_name, experiment_config, kms_key)
#    1609             job_name=job_name,
#    1610             experiment_config=experiment_config,
# -> 1611             kms_key=kms_key,
#    1612         )
#    1613
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sagemaker/workflow/pipeline_context.py in wrapper(*args, **kwargs)
#     207             return self_instance.sagemaker_session.context
#     208
# --> 209         return run_func(*args, **kwargs)
#     210
#     211     return wrapper
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sagemaker/processing.py in run(self, code, inputs, outputs, arguments, wait, logs, job_name, experiment_config, kms_key)
#     552             inputs=normalized_inputs,
#     553             outputs=normalized_outputs,
# --> 554             experiment_config=experiment_config,
#     555         )
#     556         self.jobs.append(self.latest_job)
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sagemaker/processing.py in start_new(cls, processor, inputs, outputs, experiment_config)
#     772
#     773         # Call sagemaker_session.process using the arguments dictionary.
# --> 774         processor.sagemaker_session.process(**process_args)
#     775
#     776         return cls(
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sagemaker/session.py in process(self, inputs, output_config, job_name, resources, stopping_condition, app_specification, environment, network_config, role_arn, tags, experiment_config)
#     923             self.sagemaker_client.create_processing_job(**request)
#     924
# --> 925         self._intercept_create_request(process_request, submit, self.process.__name__)
#     926
#     927     def _get_process_request(
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sagemaker/session.py in _intercept_create_request(self, request, create, func_name)
#    4201             func_name (str): the name of the function needed intercepting
#    4202         """
# -> 4203         return create(request)
#    4204
#    4205
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sagemaker/session.py in submit(request)
#     921             LOGGER.info("Creating processing-job with name %s", job_name)
#     922             LOGGER.debug("process request: %s", json.dumps(request, indent=4))
# --> 923             self.sagemaker_client.create_processing_job(**request)
#     924
#     925         self._intercept_create_request(process_request, submit, self.process.__name__)
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sagemaker/local/local_session.py in create_processing_job(self, ProcessingJobName, AppSpecification, ProcessingResources, Environment, ProcessingInputs, ProcessingOutputConfig, **kwargs)
#     124         logger.info("Starting processing job")
#     125         processing_job.start(
# --> 126             ProcessingInputs, ProcessingOutputConfig, Environment, ProcessingJobName
#     127         )
#     128
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sagemaker/local/entities.py in start(self, processing_inputs, processing_output_config, environment, processing_job_name)
#     133
#     134         self.container.process(
# --> 135             processing_inputs, processing_output_config, environment, processing_job_name
#     136         )
#     137
#
# ~/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/sagemaker/local/image.py in process(self, processing_inputs, processing_output_config, environment, processing_job_name)
#     169             # which contains the exit code and append the command line to it.
#     170             msg = f"Failed to run: {compose_command}"
# --> 171             raise RuntimeError(msg) from e
#     172         finally:
#     173             # Uploading processing outputs back to Amazon S3.
#
# RuntimeError: Failed to run: ['docker-compose', '-f', '/tmp/tmphhcm0lra/docker-compose.yaml', 'up', '--build', '--abort-on-container-exit']

# %%
from sagemaker.workflow.properties import PropertyFile

# %%
evaluation_report = PropertyFile(
    name="SceneClassifierEvaluationReport",
    output_name="evaluation",
    path="evaluation.json",
)
step_eval = ProcessingStep(
    name="EvaluateSceneClassifierModel",
    step_args=eval_step_args,
    property_files=[evaluation_report],
)

# %%
step_eval

# %% [markdown]
# ## Model Metrics

# %%
from sagemaker.model_metrics import MetricsSource, ModelMetrics
from sagemaker.workflow.properties import PropertyFile

# %%
model_metrics = ModelMetrics(
    model_statistics=MetricsSource(
        s3_uri="{}/evaluation.json".format(
            step_eval.arguments["ProcessingOutputConfig"]["Outputs"][0]["S3Output"]["S3Uri"]
        ),
        # s3_uri="s3://sagemaker-ap-south-1-006547668672/eval-flower-classifier-model-2022-12-07-19-40-04-608/output/evaluation/evaluation.json",
        content_type="application/json",
    )
)

# %% [markdown]
# ## Register Model Step (Conditional)

# %%
from sagemaker.deserializers import JSONDeserializer
from sagemaker.model import Model
from sagemaker.predictor import Predictor
from sagemaker.pytorch import PyTorchModel
from sagemaker.serializers import DataSerializer, JSONSerializer, NumpySerializer
from sagemaker.workflow.model_step import ModelStep

# %%
model_approval_status = ParameterString(
    name="ModelApprovalStatus", default_value="PendingManualApproval"
)

# %%
model_package_group_name = "SceneClassifierModelGroup"

# %%
# model = PyTorchModel(
#     entry_point="pipelines/infer.py",
#     source_dir="sagemaker-kidu",
#     image_uri = "441249477288.dkr.ecr.ap-south-1.amazonaws.com/sagemaker-inference",
#     sagemaker_session=pipeline_session,
#     role=role,
#     model_data=step_train.properties.ModelArtifacts.S3ModelArtifacts,
#     # model_data="s3://sagemaker-ap-south-1-006547668672/training-flower-pipeline-2022-12-07-03-20-21-157/output/model.tar.gz",
#     framework_version="1.11.0",
# )

# %%
# !aws ecr get-login-password --region ap-south-1 | docker login --username AWS --password-stdin 441249477288.dkr.ecr.ap-south-1.amazonaws.com

# %%
model = Model(
    image_uri="441249477288.dkr.ecr.ap-south-1.amazonaws.com/sagemaker-inference:latest",
    model_data="s3://sagemaker-project-p-yuysbbvtdpyo/pipelines-w7h248umyt5i-TrainIntelClassifier-AoArHjW6QS/output/model.tar.gz",
    role=role,
    # sagemaker_session=pipeline_session
    predictor_cls=Predictor,
)

# %%
predictor = model.deploy(
    initial_instance_count=1,
    instance_type="ml.t2.medium",
    serializer=DataSerializer(),
    deserializer=JSONDeserializer(),
)
# Out:
# -------!

# %%
# predictor_new = Predictor(
#     endpoint_name="sagemaker-inference-2023-02-03-12-33-35-382",
#     sagemaker_session=sagemaker_session,
#     serializer=DataSerializer(),
#     deserializer=JSONDeserializer(),
# )

# %%
out = predictor.predict("/home/ec2-user/SageMaker/5.jpg")

# %%
out
# Out:
# {'buildings': 0.9999991655349731,
#  'sea': 7.872914125073294e-07,
#  'street': 1.1917365982938577e-09,
#  'glacier': 7.40345840188894e-10,
#  'mountain': 2.2310342462361632e-10,
#  'forest': 4.979721929948555e-12}

# %%
model_step_args = model.register(
    content_types=["file-path/raw-bytes"],
    response_types=["application/json"],
    inference_instances=["ml.t2.medium", "ml.t2.large"],
    transform_instances=["ml.m4.xlarge"],
    model_package_group_name=model_package_group_name,
    # approval_status=model_approval_status,
    approval_status="PendingManualApproval",
    model_metrics=model_metrics,
)

# %%
step_register = ModelStep(
    name="RegisterSceneClassifierModel",
    step_args=model_step_args,
)

# %%
step_register

# %%
from sagemaker.workflow.condition_step import ConditionStep
from sagemaker.workflow.conditions import ConditionGreaterThanOrEqualTo
from sagemaker.workflow.functions import JsonGet

# %%
cond_gte = ConditionGreaterThanOrEqualTo(
    left=JsonGet(
        step_name=step_eval.name,
        property_file=evaluation_report,
        json_path="multiclass_classification_metrics.accuracy.value",
    ),
    right=0.6,
)

step_cond = ConditionStep(
    name="CheckAccuracySceneClassifierEvaluation",
    conditions=[cond_gte],
    if_steps=[step_register],
    else_steps=[],
)

# %% [markdown]
# ## Pipeline

# %%
from sagemaker.workflow.pipeline import Pipeline

# %%
pipeline_name = "PyTorchSceneClassifier"

# %%
pipeline = Pipeline(
    name=pipeline_name,
    parameters=[
        dvc_repo_url,
        dvc_branch,
        input_dataset,
        model_approval_status,
        model_name,
        batch_size,
        optimizer,
        learning_rate,
    ],
    steps=[step_process, step_train, step_eval, step_cond],
    sagemaker_session=pipeline_session,
    # sagemaker_session=local_pipeline_session,
)

# %%
upsert_response = pipeline.upsert(role_arn=role, description="testing pytorch scene pipeline")

# %%
execution = pipeline.start()

# %%
execution.list_steps()

# %%
execution.describe()
